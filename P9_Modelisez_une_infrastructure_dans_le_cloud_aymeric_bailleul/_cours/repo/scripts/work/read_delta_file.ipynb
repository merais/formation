# %%
from pyspark.sql import SparkSession

# Create a Spark session with Delta Lake extensions enabled
spark = SparkSession.builder \
    .appName("Read Delta Table") \
    .config("spark.driver.memory", "4g") \
    .config("spark.executor.memory", "4g") \
    .config("spark.driver.extraJavaOptions", "-XX:++UseG1GC") \
    .config("spark.executor.extraJavaOptions", "-XX:++UseG1GC") \
    .config("spark.sql.extensions", "io.delta.sql.DeltaSparkSessionExtension") \
    .config("spark.sql.catalog.spark_catalog", "org.apache.spark.sql.delta.catalog.DeltaCatalog") \
    .config("spark.sql.debug.maxToStringFields", "1000")  \
    .getOrCreate()

# Read the Delta table from the specified path
delta_df = spark.read.format("delta").load("orders/data")

# Display the content of the Delta table
delta_df.show()
# Out:
# +--------+-------------------+--------------------+-------------+-----------+----------+---------+---------+------------+-------------+---------+-------------------+
# |order_id|         order_date|        product_name|quantity_sold|total_sales|unit_price|promotion|   region|source_table|    source_db|operation|    event_timestamp|
# +--------+-------------------+--------------------+-------------+-----------+----------+---------+---------+------------+-------------+---------+-------------------+
# |       1|2023-01-01 00:00:00|        T-shirt bleu|           50|      999.5|     19.99|  10% off|    Paris|      orders|clicketachete|        r|2025-03-17 07:13:01|
# |       2|2023-01-01 00:00:00| Chaussures blanches|           30|      899.7|     29.99|  15% off|     Lyon|      orders|clicketachete|        r|2025-03-17 07:13:01|
# ...

# %%
print(delta_df.count())
# Out:
# 57
